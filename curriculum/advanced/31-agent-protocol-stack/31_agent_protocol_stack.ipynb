# %% [markdown]
# # Module 31 — The Agent Protocol Stack
#
# > **SDKs:** `dataclasses`
#
# | Part | Topic |
# |------|-------|
# | **1** | MCP vs A2A vs Agent Protocol — boundary selection |

# %% [markdown]
# ---
# ## Part 1 — Protocol Boundary Selection
#
# MCP is for tools. Agent Protocol is for UI-to-Agent. A2A is for Agent-to-Agent delegation.

# %%
from dataclasses import dataclass

@dataclass
class ProtocolContract:
    name: str
    boundary: str
    purpose: str

protocols = [
    ProtocolContract("MCP", "Agent ↔ Tool/Resource", "Expose read/write functions and data to the LLM"),
    ProtocolContract("Agent Protocol", "Client/UI ↔ Agent", "Start, monitor, and retrieve artifacts from an agent run"),
    ProtocolContract("A2A", "Agent ↔ Agent", "Delegate tasks to remote specialized agents"),
]

print("🌐  Agent Protocol Stack")
print("=" * 60)
for p in protocols:
    print(f"  [{p.name}]")
    print(f"    Boundary : {p.boundary}")
    print(f"    Purpose  : {p.purpose}\n")
# Out:
# 🌐  Agent Protocol Stack
# ...
#   [MCP]
#     Boundary : Agent ↔ Tool/Resource
#     Purpose  : Expose read/write functions and data to the LLM
#
#   [Agent Protocol]
#     Boundary : Client/UI ↔ Agent
#     Purpose  : Start, monitor, and retrieve artifacts from an agent run
#
#   [A2A]
#     Boundary : Agent ↔ Agent
#     Purpose  : Delegate tasks to remote specialized agents
