# %% [markdown]
# # Multi-agent research capstone
#
# Compare a manager/worker team with a single-agent baseline. Track roles, source IDs, termination, and escalation.

# %%
from pathlib import Path
exec(Path('../advanced/05_multi_agent_research_capstone.py').read_text())
run_team('agent safety')
