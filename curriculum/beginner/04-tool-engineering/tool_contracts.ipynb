# %% [markdown]
# # Tool contract lab
#
# Inspect validation, authorization, dry-run behavior, and typed errors.

# %%
from pathlib import Path
exec(Path('../beginner/02_tool_contracts.py').read_text())
